# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/Milestone 2'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.2/755.2 kB 4.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import os
from ultralytics import YOLO

# %% [markdown]
# # model train

# %%
import os
from ultralytics import YOLO

#loading model
model = YOLO("yolov8n.yaml") # build a new model from beginning

#use model
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=20)  # train the model
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/Milestone 2/'

# %% [markdown]
# model validation

# %%
# !yolo task=detect mode=val model="/content/gdrive/MyDrive/Milestone 2/runs/detect/train/weights/best.pt" data="/content/gdrive/MyDrive/Milestone 2/google_colab_config.yaml"
# Out:
# Ultralytics YOLOv8.2.6 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 16.8MB/s]
# val: Scanning /content/gdrive/MyDrive/Milestone 2/labels/valid.cache... 723 images, 8 backgrounds, 10 corrupt: 100% 723/723 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/gdrive/MyDrive/Milestone 2/images/valid/19121070_02.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/gdrive/MyDrive/Milestone 2/images/valid/19121070_04.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/gdrive/MyDrive/Milestone 2/images/valid/19121070_19.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/gdrive/MyDrive/Milestone 2/images/valid/19121070_23.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/gdrive/MyDrive/Milestone 2/images/valid/19121070_29.jpg: corrupt JPEG restored and saved
# ...

# %% [markdown]
# model test

# %%
# !yolo task=detect mode=predict model="/content/gdrive/MyDrive/Milestone 2/runs/detect/train/weights/best.pt" conf=0.25 iou=0.7 source="/content/gdrive/MyDrive/Milestone 2/images/test"
# Out:
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/362 /content/gdrive/MyDrive/Milestone 2/images/test/1038.png: 384x640 2 signboards, 260.1ms
# image 2/362 /content/gdrive/MyDrive/Milestone 2/images/test/1441.png: 384x640 2 signboards, 150.3ms
# image 3/362 /content/gdrive/MyDrive/Milestone 2/images/test/1444.png: 384x640 2 signboards, 139.2ms
# image 4/362 /content/gdrive/MyDrive/Milestone 2/images/test/1445.png: 384x640 2 signboards, 154.6ms
# image 5/362 /content/gdrive/MyDrive/Milestone 2/images/test/1451.png: 384x640 2 signboards, 158.9ms
# image 6/362 /content/gdrive/MyDrive/Milestone 2/images/test/1457.png: 384x640 3 signboards, 153.0ms
# image 7/362 /content/gdrive/MyDrive/Milestone 2/images/test/1469.png: 384x640 3 signboards, 143.8ms
# image 8/362 /content/gdrive/MyDrive/Milestone 2/images/test/1485.png: 384x640 2 signboards, 140.0ms
# ...

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# UTF-8

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/Milestone 2/'

# %%
# !yolo task=detect mode=val model="/content/gdrive/MyDrive/Milestone 2/runs/detect/train/weights/best.pt" data="/content/gdrive/MyDrive/Milestone 2/test.yaml" iou=0.7 conf=0.25
# Out:
# Ultralytics YOLOv8.2.7 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/gdrive/.shortcut-targets-by-id/16ZApVC9JakB1wFqr40j-s4ShhQjsuqQk/Milestone 2/labels/test.cache... 362 images, 2 backgrounds, 1 corrupt: 100% 362/362 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/gdrive/.shortcut-targets-by-id/16ZApVC9JakB1wFqr40j-s4ShhQjsuqQk/Milestone 2/images/test/19121070_03.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/gdrive/.shortcut-targets-by-id/16ZApVC9JakB1wFqr40j-s4ShhQjsuqQk/Milestone 2/images/test/19121070_07.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /content/gdrive/.shortcut-targets-by-id/16ZApVC9JakB1wFqr40j-s4ShhQjsuqQk/Milestone 2/images/test/19121070_15.jpg: corrupt JPEG restored and saved
# ...

# %%
# !scp -r /content/runs '/content/gdrive/MyDrive/Milestone 2/'
